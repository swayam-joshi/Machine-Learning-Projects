# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Importing data as numpyarray

# %%
data=np.genfromtxt("C:/Users/joshi/Downloads/ieeedata.csv",delimiter=",")

# %% [markdown]
# For avoiding errors and Nan renmoving the head row

# %%
data=np.delete(data,0,axis=0)
display(data)
# Out:
# array([[3.49190737e+07, 1.85860000e+04, 8.88386219e+06, 7.07169700e+06,
#         2.26225593e+03],
#        [4.11907060e+05, 6.84183000e+05, 1.36779460e+01, 7.18360560e+07,
#         8.36350000e+03],
#        [1.72273156e+05, 5.70700000e+03, 2.15739520e+00, 5.98083600e+06,
#         7.07000000e+00],
#        ...,
#        [1.79631000e+03, 4.80000000e+01, 6.34000000e-01, 8.00000000e+01,
#         1.37322263e+08],
#        [5.03505600e+06, 3.02063232e+08, 1.69713532e+04, 1.62760000e+04,
#         6.03228926e-01],
#        [3.67866325e+07, 8.95157255e+08, 6.73051131e+05, 5.10187058e+08,
#         5.19035402e+03]])

# %% [markdown]
# To apply Kmeans algorithm on this dataset we first need to convert this data to a 2D dataset for the ease of visualisation.
# For that we will use method called Principal Component Analysis or PCA which would return 2 components from this 5D dataset

# %% [markdown]
# PCA uses covariances to compare features which is sensitive to scale of data so we need to normalise the data to comparable values.
# We subract the data by the mean value and divide it by the standard deviation of that column

# %%
standardized_data = (data - data.mean(axis = 0)) / data.std(axis = 0)

# %% [markdown]
# Calculating the Covariance Matrix

# %%
covariance_matrix = np.cov(standardized_data, ddof = 0, rowvar = False)

# %% [markdown]
# By using Eigendecomposition method we find how the covariances are related to each other

# %%
#this function will return eigenvalues and eigenfucntions
eigenvalues, eigenvectors = np.linalg.eig(covariance_matrix)

# %% [markdown]
# Eigenvectors are principal components for PCA, more important components will have higher eigenvalues.
# To get right principal components, we will sort them based on their eigenvalues highest to lowest.

# %%
#arg sort gives lowest to highest using [::-1] we can reverse the list
order_of_importance = np.argsort(eigenvalues)[::-1] 
#using sort
sorted_eigenvalues = eigenvalues[order_of_importance]
sorted_eigenvectors = eigenvectors[:,order_of_importance]
#using the sorted eigenvalues to find explained variances corresponding to eignenvector which will return value between 0 to 1
explained_variance = sorted_eigenvalues / np.sum(sorted_eigenvalues)

# %% [markdown]
# We obtain the Reduced data with 2 components so now we can head to applying K means

# %%
k = 2 
X = np.matmul(standardized_data, sorted_eigenvectors[:,:k]) 
display(X)
# Out:
# array([[ 1.15690331e-01,  1.46447645e-01],
#        [ 3.40717407e-02,  1.00801705e-01],
#        [ 2.32359756e-01,  3.36843060e-02],
#        [ 2.50399125e-01,  2.73018751e-02],
#        [-3.60898186e-01,  3.67062391e-01],
#        [-8.73876225e-01,  2.26472008e-01],
#        [-6.68004550e-01, -1.52235737e+00],
#        [-2.06168804e-02,  1.20206506e-01],
#        [ 9.43998912e-03,  1.06944658e-01],
#        [-2.18437580e+00,  9.06553595e-01],
#        [ 1.49828806e-01, -1.43019157e-01],
#        [ 2.05405851e+00,  1.88204553e+00],
#        [ 8.32719313e-01,  6.35370687e-01],
#        [ 4.55211956e-01,  2.39971672e-01],
#        [-1.14645323e-02,  1.41365652e-01],
#        [ 4.68858039e-01,  2.54129856e-01],
#        [-1.66705344e+00,  9.59958578e-01],
#        [ 4.49299246e-01, -4.64769088e-01],
#        [ 1.13199184e-01, -1.30452106e-01],
#        [ 1.81751935e-01,  6.25014837e-02],
#        [-7.22726356e-01, -1.84774349e+00],
#        [ 2.77485909e-01,  7.14345901e-02],
#        [ 2.25629322e-01,  3.59045110e-02],
#        [-9.16817753e-01, -1.83501610e+00],
#        [ 1.85504428e-01, -9.96082164e-02],
#        [-4.48985104e-02, -1.08082765e+00],
#        [ 2.00991739e-01,  7.94012690e-03],
#        [ 2.51925256e+00,  2.60918042e+00],
#        [-1.82687178e-01, -8.66094271e-01],
#        [-1.87222060e+00, -2.95387338e+00],
#        [ 2.50885182e-01,  2.70583138e-02],
#        [ 1.11601440e+00,  9.26188908e-01],
#        [ 2.34221175e-01,  2.88075604e-03],
#        [ 2.50796441e-01,  2.66720992e-02],
#        [ 5.52534366e-01,  7.13141022e-01],
#        [ 2.51089945e-01,  2.73348226e-02],
#        [ 2.71329986e-01, -1.81765672e-02],
#        [ 5.38788965e-01,  3.43322969e-01],
#        [ 2.51380672e-01,  2.56811604e-02],
#        [ 2.50870588e-01,  2.70619173e-02],
#        [-5.44601776e-02,  1.08446657e-01],
#        [ 2.27753825e-01,  3.21836193e-02],
#        [ 2.50892168e-01,  2.70677457e-02],
#        [ 2.44493103e-01,  2.93218465e-02],
#        [ 1.23974565e-01, -1.89860908e-01],
#        [ 1.25143706e-01, -1.84610708e-01],
#        [ 3.38756330e-01, -1.34397751e-01],
#        [ 5.53044778e-01,  3.42808271e-01],
#        [ 2.52290036e-01,  2.95426984e-02],
#        [-2.25745837e+00,  1.53852290e+00],
#        [ 1.58293438e-01, -1.42226563e-01],
#        [ 2.52674797e-01,  2.89073729e-02],
#        [ 5.89494039e-01,  4.39456398e-01],
#        [-1.27031060e+00,  8.82541631e-01],
#        [ 1.92396900e-01,  4.74485777e-02],
#        [-1.20760588e-01,  1.34292817e-01],
#        [-1.00962166e+00,  4.69619898e-01],
#        [-2.37665222e+00,  9.45552751e-01],
#        [ 1.52415072e+00, -2.83011619e+00],
#        [-1.67059732e+00,  9.68113598e-01],
#        [ 7.84147976e-02,  1.99397079e-01],
#        [ 2.50792499e-01,  2.64524047e-02],
#        [ 9.63534107e-02,  2.65485035e-01],
#        [ 2.73325905e-01,  5.23192469e-02],
#        [ 9.42103519e-01,  7.48034267e-01],
#        [ 2.09090262e-01, -2.08605537e-02],
#        [ 2.53594715e-01,  2.07654166e-02],
#        [-4.49373959e-01, -1.07661356e+00],
#        [ 2.50518158e-01,  2.74766716e-02],
#        [ 2.51658159e-01,  2.73392778e-02],
#        [ 1.79877642e-01,  6.62087364e-02],
#        [-9.47732851e-01, -1.96998362e+00],
#        [ 2.50861880e-01,  2.70517949e-02],
#        [-1.01008035e+00, -1.51227537e+00],
#        [-1.06820360e+00,  4.90380978e-01],
#        [ 2.03543884e-01,  7.28879303e-02],
#        [ 2.53726251e-01,  3.01712025e-02],
#        [ 2.49391837e-01,  2.45438191e-02],
#        [ 2.51179558e-01,  2.74803619e-02],
#        [ 2.17412347e-01, -3.06575876e-02],
#        [ 2.46259726e-01,  1.20662393e-02],
#        [-1.84633146e+00,  1.19044842e+00],
#        [-1.36657186e+00,  5.94602351e-01],
#        [ 2.56946222e-01,  3.47082540e-02],
#        [ 1.33406517e+00, -2.40691025e+00],
#        [ 2.31413254e-01,  3.94899612e-02],
#        [-5.63401422e-01, -1.09882504e+00],
#        [ 3.16270250e-01,  9.51150331e-02],
#        [ 2.49067774e-01,  2.58625854e-02],
#        [ 2.79230188e-01, -1.01058246e-02],
#        [ 2.46997928e-01, -2.58427537e-02],
#        [-9.47220307e-03, -3.88400921e-01],
#        [ 2.50281267e-01,  2.76404114e-02],
#        [ 1.08394312e-01, -2.03976827e-01],
#        [ 2.31123107e-01,  3.76467881e-02],
#        [ 2.50995057e-01,  2.71691242e-02],
#        [-4.28369592e+00,  2.08864391e+00],
#        [-5.45872070e-01, -1.30299327e+00],
#        [ 1.68764426e+00,  1.51350705e+00],
#        [ 2.98239842e-01, -7.85459031e-02],
#        [ 2.24812228e-01,  3.74205291e-02],
#        [ 3.69484273e-01,  1.53468649e-01],
#        [ 2.44348664e-01,  2.92040515e-02],
#        [-2.33272280e+00,  9.74063761e-01],
#        [ 2.48638176e-01,  2.78084283e-02],
#        [-1.47847062e+00, -2.88406146e+00],
#        [-2.36215210e+00,  1.35255580e+00],
#        [ 2.98607181e-01,  5.98890410e-03],
#        [-6.55642733e-01, -9.35550786e-01],
#        [ 2.50747742e-01,  2.71163095e-02],
#        [ 1.71585558e+00,  1.86409253e+00],
#        [ 2.50615233e-01,  2.71817856e-02],
#        [ 1.69898584e+00,  1.54074647e+00],
#        [ 2.85892784e-01, -5.34739226e-02],
#        [ 4.81068137e-01,  1.38968237e-01],
#        [ 2.51694845e-01,  2.84572582e-02],
#        [ 1.41958263e+00, -2.72470642e+00],
#        [ 3.28830528e-01, -1.48572974e-01],
#        [ 1.73629284e-01,  5.40833242e-02],
#        [ 6.01115022e-02, -2.92390962e-01],
#        [-8.74269130e-01,  4.25289552e-01],
#        [ 2.31660170e-01,  3.37173445e-02],
#        [-5.45430534e-01,  3.06635588e-01],
#        [ 2.65320425e-01,  4.17459179e-02],
#        [ 2.50860153e-01,  2.70343109e-02],
#        [ 2.56306247e-01,  1.45776254e-02],
#        [-1.64984729e+00,  6.94381900e-01],
#        [ 2.40717504e-01,  3.06046579e-02],
#        [ 7.57967578e-02, -5.76579368e-01],
#        [ 1.23030255e+00,  1.01479148e+00],
#        [-1.41019281e+00,  6.06860923e-01],
#        [ 2.59882664e-01, -1.58386849e-01],
#        [ 3.00619361e+00,  2.65957597e+00],
#        [ 2.28557769e-01, -1.01530759e-02],
#        [-9.71368569e-01,  4.56257566e-01],
#        [ 2.72031784e-01,  5.27831859e-02],
#        [-1.51189116e+00,  1.00512110e+00],
#        [ 2.60528886e-01,  5.39259176e-03],
#        [-3.33203657e+00,  1.57056297e+00],
#        [ 1.42951999e+00, -2.73699184e+00],
#        [ 2.50086455e-01,  2.70134171e-02],
#        [ 2.41542429e-01,  1.50687926e-02],
#        [-6.53035666e-02, -1.70190703e-01],
#        [ 2.50912854e-01,  2.46510090e-02],
#        [-8.33101410e-01, -7.64852747e-01],
#        [-1.66229448e+00,  6.89586856e-01],
#        [ 6.74810232e-01,  4.68070161e-01],
#        [ 2.34335636e-01,  4.09244787e-03],
#        [ 2.77847671e-01,  6.43001927e-02],
#        [ 2.88753915e+00,  2.79463791e+00],
#        [ 2.44864477e-01,  2.98453546e-02],
#        [ 2.50387511e-01,  2.65190954e-02],
#        [ 1.05839988e-01,  1.03810932e-01],
#        [ 5.37561090e-01, -5.71984731e-01],
#        [ 2.63989851e-01,  3.98264830e-02],
#        [ 2.50780546e-01,  2.70330288e-02],
#        [ 2.51242428e-01,  2.53432296e-02],
#        [ 9.91015805e-02,  7.20303397e-02],
#        [ 6.56218854e-02,  6.67041996e-02],
#        [ 1.80809552e+00,  1.29440324e+00],
#        [ 2.43233176e-01,  1.83063035e-02],
#        [-1.80589326e+00,  7.46411266e-01],
#        [-2.08765394e+00,  1.03927463e+00],
#        [ 4.59127870e-01, -4.59225372e-01],
#        [ 4.06756144e-01, -3.24025376e-01],
#        [ 2.48840935e-01,  2.35764860e-02],
#        [-6.37050161e-01,  5.19128993e-01],
#        [-8.84010811e-02,  1.65865947e-01],
#        [ 4.22568397e-02,  1.00232083e-01],
#        [ 1.44501051e+00,  1.27106875e+00],
#        [ 4.57073730e-01,  2.41817381e-01],
#        [-6.10734167e+00, -1.28737416e+00],
#        [-1.54442579e+00, -3.01997878e+00],
#        [ 2.49635970e-01,  2.54842981e-02],
#        [ 1.86115683e-01,  4.89082334e-02],
#        [ 2.20137785e-01, -2.45523545e-01],
#        [ 5.28882117e-02, -5.73562458e-02],
#        [ 6.45938074e-01, -8.60440523e-01],
#        [ 2.52252811e-01,  2.82785799e-02],
#        [ 2.54688484e-01,  3.10965445e-02],
#        [ 2.61040702e-01,  2.13881727e-03],
#        [ 1.15125724e+00,  8.33297626e-01],
#        [ 7.49571081e-02,  1.24653669e-01],
#        [-2.51612696e+00,  1.56214052e+00],
#        [ 2.91776262e-01, -6.52691315e-02],
#        [ 2.40903986e-01,  1.59944472e-02],
#        [ 3.59790804e-01, -2.14777911e-01],
#        [-6.43014495e-01,  3.25917990e-01],
#        [ 2.89817356e-01,  7.01584082e-02],
#        [ 2.52464024e-01,  2.98486525e-02],
#        [ 2.50449420e-01,  2.58409319e-02],
#        [ 7.77567107e-01, -1.18140405e+00],
#        [-4.91671739e+00,  2.35179959e+00],
#        [ 2.50699226e-01,  2.70885225e-02],
#        [-6.26475083e-01, -2.93645652e-01],
#        [ 1.11818616e+00,  2.72923735e+00],
#        [ 1.58819814e-01, -1.27925952e-01],
#        [ 2.59729092e-01,  3.63328311e-02],
#        [ 2.39803192e-01,  8.55270014e-03],
#        [ 3.44156890e+00,  3.42607461e+00],
#        [-8.16522715e-01,  6.19110413e-01],
#        [ 2.53211567e-01,  2.12028784e-02],
#        [ 1.06390297e+00,  8.74239944e-01],
#        [-2.52872806e+00,  1.00072090e+00],
#        [ 3.69111385e-01,  1.58584821e-01],
#        [-2.75753821e+00,  1.70319706e+00],
#        [ 2.15323974e-01,  3.88232211e-02],
#        [ 2.00277798e+00,  2.02815627e+00],
#        [ 1.92764750e-01,  4.84967883e-02],
#        [-5.09855041e-01, -1.25365696e+00],
#        [ 2.55590897e-01,  1.54740739e-02],
#        [ 4.83135203e-01, -5.00067975e-01],
#        [ 1.00617058e-01, -2.30346302e-01],
#        [ 2.61165114e-01,  2.84082537e-02],
#        [ 2.50858544e-01,  2.70200636e-02],
#        [ 1.95687561e-01, -8.25176001e-02],
#        [ 2.78390972e-01, -3.00901257e-02],
#        [ 1.80311761e-01, -9.85475300e-03],
#        [ 2.47935463e+00, -5.68036925e+00],
#        [-2.51519633e+00,  8.92745697e-01],
#        [-1.28343839e+00, -2.55998287e+00],
#        [ 1.69248824e-01,  4.40638101e-02],
#        [ 1.48432904e-03,  1.24031934e-01],
#        [ 2.51182974e-01,  2.73872748e-02],
#        [-1.30693448e+00, -2.36424952e+00],
#        [-2.66698768e+00,  1.07145361e+00],
#        [ 2.48105267e-01,  2.78326978e-02],
#        [ 7.01630775e-02, -2.97415713e-01],
#        [ 2.48307886e-01,  2.83496401e-02],
#        [ 1.08457618e-01,  1.05505286e-01],
#        [ 2.02776674e+00,  1.88234045e+00],
#        [ 1.44841390e+00,  1.46395481e+00],
#        [ 2.40836215e-01,  6.45291077e-03],
#        [ 9.83358898e-01, -1.73451416e+00],
#        [-9.93218027e-01,  7.42064126e-01],
#        [-3.31199068e+00, -1.05027952e+00],
#        [ 2.48290943e-01,  2.82653048e-02],
#        [-2.18584415e+00,  8.82593208e-01],
#        [ 1.56416177e-01, -1.71948733e-01],
#        [ 3.35721665e-01,  1.07582375e-01],
#        [ 2.51390889e-01,  2.59182556e-02],
#        [-5.44948490e-01, -1.31256316e+00],
#        [ 2.48127322e-01,  2.79895102e-02],
#        [ 2.48326696e-01,  2.27586029e-02],
#        [-1.94501397e-02,  1.40600476e-01],
#        [ 2.78501901e-01,  5.58240360e-02],
#        [ 4.78231619e-01, -5.02938234e-01],
#        [-2.43176249e+00,  9.66428227e-01],
#        [-2.24543286e+00,  6.37254379e-01],
#        [ 1.12909643e-01,  7.57160528e-02],
#        [ 2.45094466e-01,  2.67404645e-02],
#        [ 2.49901814e-01,  2.49364972e-02],
#        [ 2.81178279e-01, -4.09210557e-02],
#        [-1.61214587e+00,  6.52670837e-01],
#        [ 2.89964266e+00,  4.17697089e-01],
#        [ 2.50760196e-01,  2.70868328e-02],
#        [ 2.42815123e-01,  1.32809369e-02],
#        [-2.78243448e-01,  1.97716843e-01],
#        [-2.07183987e+00,  1.27654797e+00],
#        [ 8.80778436e-02,  1.19988040e-01],
#        [-6.22863316e-01, -1.44222651e+00],
#        [ 6.81863397e-01, -9.34993191e-01],
#        [ 2.49397774e-01,  3.81375842e-02],
#        [ 1.45310543e+00,  1.20391720e+00],
#        [ 2.49769027e-01,  2.55095095e-02],
#        [-1.95058924e+00,  7.97343289e-01],
#        [ 1.77822365e-01,  6.75930621e-02],
#        [-1.03508508e+00, -2.14351088e+00],
#        [-1.02533736e+00, -2.13861204e+00],
#        [ 2.83788084e+00,  2.71825953e+00],
#        [ 2.75471169e-01,  5.40177053e-03],
#        [ 4.47654377e-03, -3.21859736e-01],
#        [ 2.20360651e-01,  2.68620860e-02],
#        [ 4.29524882e-03, -3.90084393e-01],
#        [ 2.50857190e-01,  2.70657746e-02],
#        [ 2.34039196e-01,  3.29895539e-02],
#        [ 2.58212660e-01,  3.46928136e-02],
#        [ 4.57071470e-01, -4.35647080e-01],
#        [ 2.51151502e-01,  2.59212600e-02],
#        [-3.40880666e-01, -8.93906666e-01],
#        [ 4.88861042e-01,  1.62898574e-01],
#        [ 2.49091289e-01,  2.81635462e-02],
#        [ 8.36686527e-01, -1.35229397e+00],
#        [ 1.09804487e+00, -1.82006396e+00],
#        [ 4.76468988e-01,  1.88883179e-01],
#        [-1.21313649e+00,  5.45418376e-01],
#        [ 7.00698020e-02, -2.91950999e-01],
#        [-2.92779814e-01,  3.28750116e-01],
#        [ 2.50871013e-01,  2.70614081e-02],
#        [ 2.61922502e-01,  1.94062888e-03],
#        [-7.69844230e-01,  4.15108445e-01],
#        [ 3.23126251e-01, -1.46671793e-01],
#        [ 3.29590411e-01, -1.71711697e-01],
#        [ 2.50832743e-01,  2.70666625e-02],
#        [-3.37161849e-02,  1.20748533e-01],
#        [ 2.64352041e-01, -1.48829238e-02],
#        [ 3.15077264e-01,  2.11364613e-01],
#        [ 2.51534001e-01,  2.76789991e-02],
#        [-1.95730951e-02,  1.43640320e-01],
#        [ 4.24291968e-01,  1.39733296e-01],
#        [ 1.23918081e+00,  1.02041592e+00],
#        [-1.13295537e+00,  7.95078042e-01],
#        [ 1.80295318e+00, -3.52365929e+00],
#        [ 1.77084654e-01,  1.48320211e-01],
#        [ 2.49316410e-01,  2.75678353e-02],
#        [-1.06610488e+00,  4.78609185e-01],
#        [-3.83098992e-01,  2.55535711e-01],
#        [ 2.50240698e-01,  2.72950347e-02],
#        [ 2.50806304e-01,  2.71025111e-02],
#        [ 2.54036850e-01,  1.94345731e-02],
#        [ 2.50929376e-01,  2.71040643e-02],
#        [ 3.29053208e-01, -1.09080829e-01],
#        [ 2.50894102e-01,  2.70652848e-02],
#        [-9.45210613e-01, -1.94346062e+00],
#        [-1.73632839e+00,  6.04913371e-01],
#        [ 2.50885220e-01,  2.70557758e-02],
#        [ 2.56150576e-01,  1.29531131e-02],
#        [ 2.52047511e-01,  2.99404033e-02],
#        [-5.98423324e-01,  3.27702241e-01],
#        [-2.90141447e-01, -4.19821203e-01],
#        [ 3.73508666e-01,  2.71311481e-01],
#        [ 3.63393412e-01,  1.16994735e-01],
#        [ 2.48718781e-01,  2.58044978e-02],
#        [ 2.56013848e-01,  3.18992274e-02],
#        [-5.68924591e-01, -1.35296814e+00],
#        [ 2.50862776e-01,  2.70408015e-02],
#        [ 2.12219533e+00,  1.99196374e+00],
#        [ 2.50005205e-01,  2.54252891e-02],
#        [ 1.58660176e-02, -3.67615377e-01],
#        [ 2.07220559e+00, -4.63099268e+00],
#        [ 2.36005805e-01,  3.53048370e-02],
#        [ 2.43521822e-01,  3.43417768e-02],
#        [ 2.50698305e-01,  2.67398743e-02],
#        [-2.92906422e-01,  4.30756871e-02],
#        [ 2.28762458e-01,  3.23092705e-02],
#        [ 2.42841193e-01,  1.72111816e-02],
#        [-2.69896574e+00,  1.06292424e+00],
#        [ 2.50764406e-01,  2.72898518e-02],
#        [ 2.51084495e-01,  2.72366394e-02],
#        [ 2.46341616e-01,  1.84024911e-02],
#        [-5.94638377e-01,  3.24382021e-01],
#        [ 2.41604112e-01,  1.17149022e-02],
#        [-2.52831767e+00,  5.83750237e-02],
#        [-2.17887011e-01, -8.60343918e-01],
#        [ 5.88847672e-01, -7.31659276e-01],
#        [ 2.10249684e-01,  2.41124703e-01],
#        [ 2.41089792e-01, -8.25484553e-02],
#        [ 2.65350903e-01,  5.93980166e-02],
#        [ 3.64193381e-01, -3.41814986e-01],
#        [ 1.24311889e+00,  1.06079697e+00],
#        [-6.39185152e-01,  5.14727183e-01],
#        [ 1.33441060e+00,  1.15675544e+00],
#        [ 2.66318113e+00,  2.54912707e+00],
#        [ 9.74210310e-02, -2.31289238e-01],
#        [ 2.52375445e+00,  2.45933280e+00],
#        [ 2.48529859e-01,  2.63575662e-02],
#        [ 2.32256025e-01,  3.85648024e-02],
#        [-6.82931453e-01, -1.52490603e+00],
#        [ 2.67387287e-01, -1.00243625e-02],
#        [-2.44066250e+00,  9.73987386e-01],
#        [-3.02239665e-01,  2.21517731e-01],
#        [-7.44671443e-01,  3.76620747e-01],
#        [ 2.19306872e+00,  2.04724004e+00],
#        [ 2.50724201e-01,  2.70999478e-02],
#        [ 3.46160944e-01,  1.45108482e-01],
#        [-3.46148121e+00,  2.08050661e+00],
#        [ 2.66516440e+00, -5.39046181e+00],
#        [ 2.34973565e-01, -4.44749849e-03],
#        [-8.55294619e-01,  5.60292278e-01],
#        [ 1.42061311e+00, -2.61460133e+00],
#        [ 2.52729066e-01, -1.59994250e-02],
#        [ 6.97372921e-02, -3.14846730e-01],
#        [ 2.77247223e-01,  5.28126507e-02],
#        [ 2.39670309e-01,  3.09900121e-02],
#        [ 2.12282519e-01,  4.82871920e-02],
#        [ 2.50853208e-01,  2.70625355e-02],
#        [-1.68394383e+00, -3.11821969e+00],
#        [-2.11532503e+00,  8.56983110e-01],
#        [ 2.69325899e-01, -1.43630346e-02],
#        [ 2.34430021e-01,  4.48264805e-04],
#        [ 7.43356498e-01, -1.08490270e+00],
#        [ 4.50771944e-02,  6.26172440e-02],
#        [ 1.53973767e+00,  1.25046867e+00],
#        [ 2.57966909e-01,  5.78718237e-03],
#        [-9.99420760e-01, -2.07581273e+00],
#        [ 4.70201624e-01, -4.10367309e+00],
#        [ 2.50340021e-01,  2.73575188e-02],
#        [-1.99511304e+00, -4.02372360e+00],
#        [-7.97646401e-01,  3.97864833e-01],
#        [ 1.29419764e+00, -2.33357477e+00],
#        [-1.24730900e+00, -2.49632366e+00],
#        [ 2.42216525e-01,  1.23071358e-02],
#        [ 2.50944777e-01,  2.61939028e-02],
#        [ 2.72551590e-01,  5.07863868e-02],
#        [-1.66339001e-02,  1.21022291e-01],
#        [ 2.80276600e-01,  6.79974563e-02],
#        [ 2.44719883e-01, -2.61166301e-02],
#        [ 2.50527197e-01,  2.71765696e-02],
#        [ 3.67736613e-01,  1.66092933e-01],
#        [ 1.40374784e-01,  8.64467566e-02],
#        [ 2.51252103e-01,  2.37088727e-02],
#        [-2.10867681e-01, -7.66935683e-01],
#        [ 2.52792110e-01,  2.90306946e-02],
#        [-6.77444290e-01, -1.52700004e+00],
#        [ 2.49933456e-01,  2.64774599e-02],
#        [-1.63400196e+00,  1.07267224e+00],
#        [ 1.39216836e-01, -1.75215683e-01],
#        [ 5.20917332e-01,  3.08249722e-01],
#        [ 9.33580857e-01,  7.38641576e-01],
#        [ 1.52664220e+00,  1.16836403e+00],
#        [-9.02894355e-01,  4.83058590e-01],
#        [ 6.87564516e-02,  1.24525178e-01],
#        [ 2.16411472e-01,  4.61865390e-02],
#        [ 6.73460849e-01,  4.67695319e-01],
#        [ 1.46798562e-01,  6.24123429e-02],
#        [ 2.46492595e-01,  2.84764588e-02],
#        [ 1.89479217e-01,  6.09509700e-02],
#        [ 2.30762129e-01, -1.63203357e-03],
#        [ 2.41926537e-01,  2.86567064e-02],
#        [ 2.50652358e-01,  2.68640013e-02],
#        [ 2.50953310e-01,  2.71416592e-02],
#        [ 7.03767174e-01,  4.95635727e-01],
#        [ 2.39922804e-01,  8.64971709e-03],
#        [ 2.85325942e-01,  7.03750228e-02],
#        [ 2.47130404e-01,  2.30687406e-02],
#        [-8.23961528e-01, -1.88671650e+00],
#        [ 1.02773677e+00, -2.48913948e+00],
#        [ 2.89217463e-01,  2.05715604e-01],
#        [ 2.58352226e-01,  3.48906599e-02],
#        [-1.62906215e-02,  1.20874014e-01],
#        [ 1.66719236e+00,  1.53777006e+00],
#        [ 3.66164874e-01,  1.94213574e-01],
#        [ 2.17570146e-01,  7.80572761e-02],
#        [ 1.63884660e-01,  7.16847390e-02],
#        [ 2.48113625e-01,  2.56616478e-02],
#        [ 3.41879179e-01, -1.30863725e-01],
#        [-1.75462270e-01, -3.62150980e-01],
#        [ 2.34870969e-01,  3.86392192e-02],
#        [ 2.68482743e-01, -7.70424445e-03],
#        [-2.71850771e+00,  1.26717902e+00],
#        [ 2.74411836e+00,  2.62486143e+00],
#        [-1.46858747e+00,  6.39445294e-01],
#        [ 2.62771058e-01,  3.60970777e-02],
#        [-2.60742470e+00,  1.03074542e+00],
#        [-5.10025258e+00,  2.67669541e+00],
#        [ 2.47833811e-01,  2.75997639e-02],
#        [ 4.78173495e-01, -4.82977141e-01],
#        [-2.09898600e+00,  8.43606083e-01],
#        [ 5.51104587e-02, -1.64456882e-02],
#        [-1.40623776e+00,  1.47605485e+00],
#        [ 2.40573357e-01,  3.10547146e-02],
#        [-6.49243455e-01, -1.48875988e+00],
#        [ 2.50778692e-01,  5.08192795e-02],
#        [ 2.66103747e+00,  6.28823875e-02],
#        [ 2.07635323e-01,  3.07634601e-02],
#        [ 2.61023120e-01,  1.35637509e-03],
#        [ 2.10235458e-01, -4.21670208e-02],
#        [ 2.93971249e-01, -6.96401507e-02],
#        [ 2.43895017e-01,  2.94813000e-02],
#        [ 7.63947366e-01, -1.37854810e+00],
#        [-6.01096261e-01,  3.26322550e-01],
#        [ 8.29766759e-02, -2.57370693e-01],
#        [ 2.58124620e-01,  3.46152956e-02],
#        [-4.48463300e-01,  5.44386600e-01],
#        [ 4.81896054e-01,  2.67722237e-01],
#        [ 2.50480996e-01, -1.24365888e-02],
#        [ 2.83790458e-01, -4.70614184e-02],
#        [ 2.35100484e-01,  3.25297558e-02],
#        [ 3.96502551e-02,  1.35972406e-01],
#        [ 1.79989801e-01,  6.11865391e-02],
#        [-1.36176201e+00, -2.68284015e+00],
#        [-1.48392684e-02, -3.32369817e-01],
#        [ 2.35418131e-01,  4.96652430e-03],
#        [-3.36202507e-01, -9.10442785e-01],
#        [-8.62459694e-01,  6.43477470e-01],
#        [ 2.52495397e-01,  2.86275837e-02],
#        [ 1.28454805e-01, -2.09964512e-01],
#        [-7.45266520e-01,  5.76989928e-01],
#        [ 2.50195668e-01,  2.58456841e-02],
#        [ 1.85990724e-01, -5.34782377e-02],
#        [ 2.49585750e-01,  2.79348801e-02],
#        [ 2.52014904e-01,  2.82069843e-02],
#        [-1.39115465e+00, -7.33579398e-01],
#        [ 9.63090412e-01,  7.70286590e-01],
#        [-9.90974917e-01,  7.52749393e-01],
#        [ 2.43803139e-01,  4.46179135e-02],
#        [ 2.51165984e-01,  2.61690602e-02],
#        [ 2.47238378e+00,  2.21280711e+00],
#        [ 2.50185960e-01,  2.73474451e-02],
#        [ 2.51911988e-01,  2.81264402e-02],
#        [-2.40851110e-01,  8.51811597e-02],
#        [-4.05051488e-01, -1.07722210e+00],
#        [-2.08595261e+00,  1.07821597e+00],
#        [ 2.40040762e-01,  4.89652389e-03],
#        [ 2.50946148e-01,  2.69071457e-02],
#        [ 2.49050730e-01,  2.62875461e-02],
#        [ 2.53406006e-01,  2.13977836e-02],
#        [ 6.29867821e-01, -8.23379813e-01],
#        [-3.54657065e-01, -9.45540420e-01],
#        [-3.15037038e+00, -2.26957280e+00]])

# %%
df=pd.DataFrame(X,columns=['PCA1','PCA2'])

# %%
df #displaying PCA data
# Out:
#          PCA1      PCA2
# 0    0.115690  0.146448
# 1    0.034072  0.100802
# 2    0.232360  0.033684
# 3    0.250399  0.027302
# 4   -0.360898  0.367062
# ..        ...       ...
# 495  0.249051  0.026288
# 496  0.253406  0.021398
# 497  0.629868 -0.823380
# 498 -0.354657 -0.945540
# 499 -3.150370 -2.269573
#
# [500 rows x 2 columns]

# %%
plt.scatter(df["PCA1"],df["PCA2"])

# %% [markdown]
# Now we make a function which will intialize random centroids

# %%
def random_centroids(K, X):
    m, n = np.shape(X)
    centroids = np.empty((K, n))
    for i in range(K):
        centroids[i] =  X[np.random.choice(range(m))] 
    return centroids

# %% [markdown]
# Function to find eucledian distance between two data points

# %%
def distance(x1, x2):
    return np.sqrt(np.sum(np.power(x1 - x2, 2)))

# %% [markdown]
# This function Compares distances between data points and intial centroids

# %%
def nearest_centroid(x, centroids, K):
    """Finds and returns the index of the closest centroid for a given vector x"""
    distances = np.empty(K)
    for i in range(K):
        distances[i] = distance(centroids[i], x)
    return np.argmin(distances)

# %% [markdown]
# This function lables datapoints according to number of clusters (K)

# %%
def cluster(centroids, K, X):
    """Returns an array of cluster indices for all the data samples"""
    m, _ = np.shape(X)
    cluster_idx = np.empty(m)
    for i in range(m):
        cluster_idx[i] = nearest_centroid(X[i], centroids, K)
    return cluster_idx

# %% [markdown]
# Computing Mean to update the cluster centroids

# %%
def compute_means(cluster_idx, K, X):
    
    _, n = np.shape(X)
    centroids = np.empty((K, n))
    for i in range(K):
        points = X[cluster_idx == i] # gather points for the cluster i
        centroids[i] = np.mean(points, axis=0) # use axis=0 to compute means across points
    return centroids

# %% [markdown]
# Finally Compiling all function to run Kmeans algorithm

# %%
def Kmeans(K, X, max_iterations=500):
    centroids = random_centroids(K, X)
    # loop till max_iterations or convergance
    print(f"initial centroids: {centroids}")
    for _ in range(max_iterations):
        # create clusters by assigning the samples to the closet centroids
        clusters = cluster(centroids, K, X)
        previous_centroids = centroids                                                                                                                                                                                                                                                                                                                                                                                                                                                                              
        # compute means of the clusters and assign to centroids
        centroids = compute_means(clusters, K, X)
        # if the new_centroids are the same as the old centroids, return clusters
        diff = previous_centroids - centroids
        if not diff.any():
            return clusters
    return clusters

# %% [markdown]
# Using elbow method I have found out optimal clusters are 5 for this case
# cannot display elbow method because i would need scikit learn library to show it

# %%
y_kmeans=Kmeans(5,X)
# Out:
# initial centroids: [[-0.30223967  0.22151773]
#  [ 1.45310543  1.2039172 ]
#  [ 1.42061311 -2.61460133]
#  [-0.0094722  -0.38840092]
#  [ 0.36948427  0.15346865]]

# %% [markdown]
# Visualising the Kmeans clustering by ploting

# %% [markdown]
# NOTE: Please click RUN ALL multiple times (atleast 5-6 times) to get the optimal solution because it is randomized.

# %% [markdown]
# OPTIMAL SOLUTION will have 1 cluster in the center and 4 on each side of the data

# %%
plt.scatter(X[y_kmeans==0, 0], X[y_kmeans==0, 1], c='red', label ='Cluster 1')
plt.scatter(X[y_kmeans==1, 0], X[y_kmeans==1, 1], c='blue', label ='Cluster 2')
plt.scatter(X[y_kmeans==2, 0], X[y_kmeans==2, 1], c='green', label ='Cluster 3')
plt.scatter(X[y_kmeans==3, 0], X[y_kmeans==3, 1], c='cyan', label ='Cluster 4')
plt.scatter(X[y_kmeans==4, 0], X[y_kmeans==4, 1], c='magenta', label ='Cluster 5')


plt.title('Kmeans')
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.show()
